# %%
# %matplotlib notebook

# import cv2  # python OpenCV
import os  # 
import numpy as np  # lib for arrays
import datetime
import glob
import pandas as pd

import math as mh  # math package

import matplotlib as mpl  
import matplotlib.pyplot as plt  # namespace for plotting
mpl.rcParams['figure.figsize'] = (6,5)  # change default value of plot size

# matplotlib based package for pretty visualization
import seaborn as sns

import time
import pickle  # package for dump & load data
import warnings

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
df_grouped = pd.crosstab(tips['sex'], (tips['tip'] > 0)) # количество заплативших чаевые среди женщин и мужчин
df_grouped
# Out:
# tip     True
# sex
# Male     157
# Female    87

# %%
sm_1 = tips['smoker'].value_counts(sort=False) #для самопроверки
sm_1
# Out:
# Yes     93
# No     151
# Name: smoker, dtype: int64

# %%
sm_2=pd.crosstab(tips.sex, tips.smoker,margins=True) #группировка данных
sm_2
# Out:
# smoker  Yes   No  All
# sex
# Male     60   97  157
# Female   33   54   87
# All      93  151  244

# %%
pr_f=sm_2.iloc[1]['Yes']/sm_2.iloc[1]['All'] 
pr_m=sm_2.iloc[0]['Yes']/sm_2.iloc[1]['All']

print (pr_f)               # Доля курящих среди женщин
pr_m                       # Доля курящих среди женщин
# Out:
# 0.3793103448275862
# 0.6896551724137931

# %%
tips.loc[tips['size'].idxmax()] #просто метод потестила
# Out:
# total_bill      29.8
# tip              4.2
# sex           Female
# smoker            No
# day             Thur
# time           Lunch
# size               6
# Name: 125, dtype: object

# %%
tips.groupby(by='day')['size'].mean() #день с наибольшим количеством посетителей
# Out:
# day
# Thur    2.451613
# Fri     2.105263
# Sat     2.517241
# Sun     2.842105
# Name: size, dtype: float64

# %%
tips.groupby(by='time')['tip'].max()  #наибольшее количество чаевых
# Out:
# time
# Lunch      6.7
# Dinner    10.0
# Name: tip, dtype: float64

# %%
max_row=np.argmax(tips['total_bill'].values) 
tips['day'].values[max_row]          #заказ с максимальным счетом
# Out:
# 'Sat'

# %%
gr_1=tips [['day','total_bill','smoker']]  #серия действий для построения графика
gr_1
# Out:
#       day  total_bill smoker
# 0     Sun       16.99     No
# 1     Sun       10.34     No
# 2     Sun       21.01     No
# 3     Sun       23.68     No
# 4     Sun       24.59     No
# 5     Sun       25.29     No
# 6     Sun        8.77     No
# 7     Sun       26.88     No
# 8     Sun       15.04     No
# 9     Sun       14.78     No
# 10    Sun       10.27     No
# 11    Sun       35.26     No
# 12    Sun       15.42     No
# 13    Sun       18.43     No
# 14    Sun       14.83     No
# 15    Sun       21.58     No
# 16    Sun       10.33     No
# 17    Sun       16.29     No
# 18    Sun       16.97     No
# 19    Sat       20.65     No
# 20    Sat       17.92     No
# 21    Sat       20.29     No
# 22    Sat       15.77     No
# 23    Sat       39.42     No
# 24    Sat       19.82     No
# 25    Sat       17.81     No
# 26    Sat       13.37     No
# 27    Sat       12.69     No
# 28    Sat       21.70     No
# 29    Sat       19.65     No
# ..    ...         ...    ...
# ...

# %%
gr_1['smoker'].unique().tolist()
# Out:
# ['No', 'Yes']

# %%
anti_smokers=gr_1.loc[gr_1['smoker']=='No']
anti_smokers
# Out:
#       day  total_bill smoker
# 0     Sun       16.99     No
# 1     Sun       10.34     No
# 2     Sun       21.01     No
# 3     Sun       23.68     No
# 4     Sun       24.59     No
# 5     Sun       25.29     No
# 6     Sun        8.77     No
# 7     Sun       26.88     No
# 8     Sun       15.04     No
# 9     Sun       14.78     No
# 10    Sun       10.27     No
# 11    Sun       35.26     No
# 12    Sun       15.42     No
# 13    Sun       18.43     No
# 14    Sun       14.83     No
# 15    Sun       21.58     No
# 16    Sun       10.33     No
# 17    Sun       16.29     No
# 18    Sun       16.97     No
# 19    Sat       20.65     No
# 20    Sat       17.92     No
# 21    Sat       20.29     No
# 22    Sat       15.77     No
# 23    Sat       39.42     No
# 24    Sat       19.82     No
# 25    Sat       17.81     No
# 26    Sat       13.37     No
# 27    Sat       12.69     No
# 28    Sat       21.70     No
# 29    Sat       19.65     No
# ..    ...         ...    ...
# ...

# %%
asm=anti_smokers.groupby(by='day')['total_bill'].median()
asm
# Out:
# day
# Thur    15.950
# Fri     19.235
# Sat     17.820
# Sun     18.430
# Name: total_bill, dtype: float64

# %%
smokers=gr_1.loc[gr_1['smoker']=="Yes"]
smokers
# Out:
#       day  total_bill smoker
# 56    Sat       38.01    Yes
# 58    Sat       11.24    Yes
# 60    Sat       20.29    Yes
# 61    Sat       13.81    Yes
# 62    Sat       11.02    Yes
# 63    Sat       18.29    Yes
# 67    Sat        3.07    Yes
# 69    Sat       15.01    Yes
# 72    Sat       26.86    Yes
# 73    Sat       25.28    Yes
# 76    Sat       17.92    Yes
# 80   Thur       19.44    Yes
# 83   Thur       32.68    Yes
# 90    Fri       28.97    Yes
# 92    Fri        5.75    Yes
# 93    Fri       16.32    Yes
# 95    Fri       40.17    Yes
# 96    Fri       27.28    Yes
# 97    Fri       12.03    Yes
# 98    Fri       21.01    Yes
# 100   Fri       11.35    Yes
# 101   Fri       15.38    Yes
# 102   Sat       44.30    Yes
# 103   Sat       22.42    Yes
# 105   Sat       15.36    Yes
# 106   Sat       20.49    Yes
# 107   Sat       25.21    Yes
# 109   Sat       14.31    Yes
# 138  Thur       16.00    Yes
# 164   Sun       17.51    Yes
# ..    ...         ...    ...
# ...

# %%
sm=smokers.groupby(by='day')['total_bill'].median()
sm
# Out:
# day
# Thur    16.47
# Fri     13.42
# Sat     20.39
# Sun     23.10
# Name: total_bill, dtype: float64

# %%
hist = pd.concat([asm,sm], axis=1)
hist
# Out:
#       total_bill  total_bill
# day
# Thur      15.950       16.47
# Fri       19.235       13.42
# Sat       17.820       20.39
# Sun       18.430       23.10

# %%
hist.columns.values[0] = "good_lungs"
hist.columns.values[1] = "not_so_good"
hist
# Out:
#       good_lungs  not_so_good
# day
# Thur      15.950        16.47
# Fri       19.235        13.42
# Sat       17.820        20.39
# Sun       18.430        23.10

# %%
hist.groupby('day').sum().plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="600">
