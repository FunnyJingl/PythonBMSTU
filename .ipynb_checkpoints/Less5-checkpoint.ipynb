# %% [markdown]
# # Занятие 5.
# __1. Bagging__
#
# __2. Случайный лес__
#
# __3. XGBoost__
#
# Основная часть материалов из этого занятия получены из:
# 1) [Elements of statistical learning](https://web.stanford.edu/~hastie/Papers/ESLII.pdf)
# 2) [Открытый курс по машинному обучению Юрия Кашницкого](https://github.com/Yorko/mlcourse.ai)

# %%
# Firstly import all required packages
# enable interactive mode of matplotlib
# %matplotlib notebook

# import cv2  # python OpenCV
import os  # 
import numpy as np  # lib for arrays
import datetime
import glob
import pandas as pd

import math as mh  # math package

import matplotlib as mpl  
import matplotlib.pyplot as plt  # namespace for plotting
mpl.rcParams['figure.figsize'] = (6,5)  # change default value of plot size

# matplotlib based package for pretty visualization
import seaborn as sns
plt.style.use('seaborn')
from sklearn.datasets import load_iris
from sklearn.model_selection import KFold, train_test_split

import time
import pickle  # package for dump & load data
import warnings

# %% [markdown]
# # <center> Bagging </center>
#
# Рассмотрим следующий вопрос: можно ли из комбинации слабых моделей создать более сильную модель?
#
# Ответ: да.
#
# В общем случае техника комбинации более слабых моделей в более сильную называется [ансамблями](https://web.engr.oregonstate.edu/~tgd/publications/mcs-ensembles.pdf).
#
# Предпосылкой создания ансамблей служил некоторый накопленный опыт:
# * [Мудрость толпы](https://www.ozon.ru/context/detail/id/3352273/) (Wisdom of crowds):
#     * В 1906 году британский ученый сэр Фрэнсис Гальтон посещал выставку достижений животноводства, где случайно провел крайне важное наблюдение. На выставке проводился конкурс, в рамках которого всем желающим предлагалось на глаз угадать точный вес забитого быка. Побеждал тот, кто называл самое близкое к истинному значение. Полагая, что справиться с подобной задачей под силу только профессионалу, и чтобы доказать некомпетентность толпы, Гальтон посчитал среднее значение из почти 800 догадок посетителей ярмарки. К удивлению ученого, толпа ошиблась меньше, чем на килограмм: точный вес быка 1198 фунтов, среднее значение толпы 1197 фунтов.
#     * Новое и [неслучайное исследование](https://www.nature.com/articles/s41562-017-0247-6) "внутренней" мудрости толпы проводилось нидерландскими и британскими учёными в 2013-2015 г. Исследование проводилось в сети нидерландских казино каждый год в течение последних 7 предновогодних недель. Каждому посетителю было предложено угадать количество мелких предметов в большом бокале. Количество предметов в бокале было от 12 до 23 тысяч штук. По результату было получено 1,2 млн ответов. Данное исследование показало улучшение качества предсказаний с каждой последующей попыткой угадывания, но точность этих предсказаний улучшалась незначительно.
# * **Теорема Кондорсе "О жюри присяжных" (Condorcet Jury Theorem, 1784).** *Если каждый член жюри присяжных имеет независимое мнение, и если вероятность правильного решения члена жюри больше 0,5, то тогда вероятность правильногорешения присяжных в целом возрастает с увеличением количества членов жюри, и стремиться к единице. Еслиже вероятность быть правым у каждого из членов жюри меньше 0.5, то вероятность принятия правильногорешения присяжными в целом монотонно уменьшается и стремится к нулю с увеличением количества присяжных.*
#
# $$\LARGE \mu = \sum_{i=m}^{N}C_N^i p^i (1-p)^{N-i} $$
#
# $ \mu $ - вероятность правильного решения всего жюри;
#
# $ m = floor\left(\dfrac{N}{2} + 1\right) $ - минимальное большинство членов жюри;
#
# $ N $ - число членов жюри;
#
# $ p $ - вероятность правильного решения одного члена жюри;
#
# Если $p>0,5$, то $\mu > p $, если $p<0,5$, то $\mu < p $.
#
# Если $N \rightarrow \infty$ и $p < 0,5$, то $\mu \rightarrow 0$.
#
# Если $N \rightarrow \infty$ и $p>0,5$, то $\mu \rightarrow 1$.
#
# <table>
#  <tr>
#   <td>
#    <img src="images/wisdom.jpg" height="350" width="350">
#   </td>
#   <td>
#    <img src="images/bokal.jpg" height="350" width="350">
#   </td>
#   <td>
#     <img src="images/judge.jpg" height="350" width="350">
#   </td>
#  </tr>
# </table>
#
# ## <center> Bagging (Bootstrap aggregation) </center>
#
# Наиболее распространённая техника ансамблирования моделей. *Bagging* был разработан [Лео Брейманом в 1994 году](https://www.stat.berkeley.edu/~breiman/bagging.pdf). Бэггинг основан на статистическом методе [**бутстрэпа (bootstrap)**](http://jeti.uni-freiburg.de/studenten_seminar/stud_sem_SS_09/EfronBootstrap.pdf), который позволяет оценивать многие статистики более сложных распределений.
#
# Опишем технику *bootstrap*. Пусть датасет содержит $ N $ примеров: $\mathbf{X} = \{\mathbf{x_1}, \ldots, \mathbf{x_N}\}$. Создадим новый датасет $ \mathbf{X_B} $ с возвращением. Каждый пример в $ \mathbf{X_B} $ взят случайным образом из $\mathbf{X} $ с равной вероятностью $ \dfrac{1}{N}$. Повторим описанную процедуру $ M $ раз, то есть создадим $ M $ выборок: $ \mathbf{X_B^1}, \ldots, \mathbf{X_B^M} $.
#
# <img src="images/bootstrap.png"/>
#
# Применин технику бутстрэпа к обучающей выборке $ \mathbf{X} $ и сгенерируем выборки $ \mathbf{X_B^1}, \ldots, \mathbf{X_B^M} $. На каждой из созданных выборок обучим модель $a_i(x) $. Создадим модель $ a(x) $, которая будет усреднять предсказания каждой из обученной модели:
#
# $$ \LARGE a(x) = \dfrac{1}{M}\sum_{i=1}^{M} a_i(x) $$.
#
# <img src="images/bagging.jpeg"/>

# %% [markdown]
# Рассмотрим [пример регрессии](https://scikit-learn.org/stable/auto_examples/ensemble/plot_bias_variance.html#sphx-glr-auto-examples-ensemble-plot-bias-variance-py) из документации к Scikit-Learn. Для этого сгенерируем данные в виде функции:
#
# $$ \Large  f(x) = e^{-x^2} + 1,5 \cdot e^{-(x-2)^2} $$.

# %%
def f(x):
    x = x.ravel()
    return np.exp(-x ** 2) + 1.5 * np.exp(-(x - 2) ** 2)

# %% [markdown]
# Установим параметры генерируемых данных:
# * `n_repeat` - число итераций для расчета мат. ожиданий
# * `n_train` - размер обучающей выборки
# * `n_test` - размер тестовой выборки
# * `noise` - стандартного отклонение шума
# * `random_seed` - состояние генератора случайных чисел

# %%
# Settings
n_repeat = 50       # Number of iterations for computing expectations
n_train = 50        # Size of the training set
n_test = 1000       # Size of the test set
noise = 0.1         # Standard deviation of the noise
random_seed = 0

# %% [markdown]
# Создадим функцию, которая будет генерировать искомую функцию с заданными параметрами.

# %%
def generate(n_samples, noise, n_repeat=1):
    X = np.random.rand(n_samples) * 10 - 5
    X = np.sort(X)

    if n_repeat == 1:
        y = f(X) + np.random.normal(0.0, noise, n_samples)
    else:
        y = np.zeros((n_samples, n_repeat))

        for i in range(n_repeat):
            y[:, i] = f(X) + np.random.normal(0.0, noise, n_samples)

    X = X.reshape((n_samples, 1))

    return X, y

# %% [markdown]
# Импортируем `DecisionTreeRegressor`, `BaggingRegressor` и `LinearRegression`.

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
# Change this for exploring the bias-variance decomposition of other
# estimators. This should work well for estimators with high variance (e.g.,
# decision trees or KNN), but poorly for estimators with low variance (e.g.,
# linear models).
np.random.seed(random_seed)
estimators = [("Tree", DecisionTreeRegressor()),
              ("kNN Regression", KNeighborsRegressor()),
              ("Bagging(Tree)", BaggingRegressor(DecisionTreeRegressor()))]

n_estimators = len(estimators)

X_train = []
y_train = []

for i in range(n_repeat):
    X, y = generate(n_samples=n_train, noise=noise)
    X_train.append(X)
    y_train.append(y)

X_test, y_test = generate(n_samples=n_test, noise=noise, n_repeat=n_repeat)

plt.figure(figsize=(9.5, 10))

# Loop over estimators to compare
for n, (name, estimator) in enumerate(estimators):
    # Compute predictions
    y_predict = np.zeros((n_test, n_repeat))

    for i in range(n_repeat):
        estimator.fit(X_train[i], y_train[i])
        y_predict[:, i] = estimator.predict(X_test)

    # Bias^2 + Variance + Noise decomposition of the mean squared error
    y_error = np.zeros(n_test)

    for i in range(n_repeat):
        for j in range(n_repeat):
            y_error += (y_test[:, j] - y_predict[:, i]) ** 2

    y_error /= (n_repeat * n_repeat)

    y_noise = np.var(y_test, axis=1)
    y_bias = (f(X_test) - np.mean(y_predict, axis=1)) ** 2
    y_var = np.var(y_predict, axis=1)

    print("{0}: {1:.4f} (error) = {2:.4f} (bias^2) "
          " + {3:.4f} (var) + {4:.4f} (noise)".format(name,
                                                      np.mean(y_error),
                                                      np.mean(y_bias),
                                                      np.mean(y_var),
                                                      np.mean(y_noise)))

    # Plot figures
    plt.subplot(2, n_estimators, n + 1)
    plt.plot(X_test, f(X_test), "b", label="$f(x)$")
    plt.plot(X_train[0], y_train[0], ".b", label="LS ~ $y = f(x)+noise$")

    for i in range(n_repeat):
        if i == 0:
            plt.plot(X_test, y_predict[:, i], "r", label=r"$\^y(x)$")
        else:
            plt.plot(X_test, y_predict[:, i], "r", alpha=0.05)

    plt.plot(X_test, np.mean(y_predict, axis=1), "c",
             label=r"$\mathbb{E}_{LS} \^y(x)$")

    plt.xlim([-5, 5])
    plt.title(name)

    if n == n_estimators - 1:
        plt.legend(loc=(1.1, .5))

    plt.subplot(2, n_estimators, n_estimators + n + 1)
    plt.plot(X_test, y_error, "r", label="$error(x)$")
    plt.plot(X_test, y_bias, "b", label="$bias^2(x)$"),
    plt.plot(X_test, y_var, "g", label="$variance(x)$"),
    plt.plot(X_test, y_noise, "c", label="$noise(x)$")

    plt.xlim([-5, 5])
    plt.ylim([0, 0.1])

    if n == n_estimators - 1:

        plt.legend(loc=(1.1, .5))

plt.subplots_adjust(right=.75)
# Out:
# <img src="data:image/png;base64,..." width="950">
# Tree: 0.0255 (error) = 0.0003 (bias^2)  + 0.0152 (var) + 0.0098 (noise)
# kNN Regression: 0.0210 (error) = 0.0028 (bias^2)  + 0.0082 (var) + 0.0098 (noise)
# Bagging(Tree): 0.0196 (error) = 0.0004 (bias^2)  + 0.0092 (var) + 0.0098 (noise)

# %% [markdown]
# Итоговое выражение показывает плюсы использования бэггинга.
#
# Давайте рассмотрим более подробно выражение для регрессии. Запишем ошибку каждой из модели $ b_i(x) $:
#
# $$ \LARGE \varepsilon_i = b_i(x) - y(x), \, i=1\ldots n $$.
#
# Найдем мат. ожидание MSE:
#
# $$ \LARGE \mathbb{E_x}(b_i(x) - y_i)^2 = \mathbb{E_x} \varepsilon_i(x)^2 $$.
#
# Тогда средняя ошибка моделей $ b_i(x) $ имеет вид:
#
# $$\LARGE E_{model} = \dfrac{1}{n} \mathbb{E_x}\sum_{i=1}^{n} \varepsilon^2_i(x) $$.
#
# Ошибки являются несмещёнными и нескореллированными:
#
# $$ \large \mathbb{E}_x\varepsilon_i(x) = 0 $$
#
# $$ \large \mathbb{E_x}\varepsilon_i(x)\varepsilon_j(x) = 0, i \neq j $$
#
# Построим модель регрессора, которая усредняет предсказания каждой из отдельных моделей:
#
# $$ \large a(x) = \dfrac{1}{n} \sum_{i=1}^{n} b_i(x) $$
#
# и найдем её MSE:
#
# $$ \large E_n = \left(\dfrac{1}{n} \sum_{i=1}^{n} b_i(x) - y(x)\right)^2 = \mathbb{E}_x\left( \dfrac{1}{n} \sum_{i=1}^{n} \varepsilon_i \right)^2 = \dfrac{1}{n^2} \mathbb{E}_x \left( \sum_{i=1}^{n} \varepsilon^2_i(x) + \sum_{i \neq j} \varepsilon_i(x)\varepsilon_j(x) \right) =  \dfrac{1}{n} E_{model} $$.
#
# Таким образом, использование бэггинга позволило уменьшить MSE в $n$ раз. Ошибка MSE соответствует компоненте разброса $ Var $  в разложении ошибки:
#
# $$\Huge Err(\overrightarrow{x}) = Bias\left(\hat{f}\right)^2 + Var\left(\hat{f}\right) + \sigma^2$$

# %% [markdown]
# # <center> Случайный лес </center>
#
# <img src="images/forest.jpg">
#
#
# <hr style="height:3px">
# Алгоритм построения случайного леса для регрессии или классификации
# <hr style="height:3px">
# 1. Для $b=1\ldots B $:
#
#     1. Сгенерировать бутстрэп выборку $Z^*$ размера $ N $ от обучающей выборки.
#
#     2. Построить решающее дерево $ T_b $ по бутстрэп выборке $Z^*$ рекурсивным перебором следующих шагов для каждого разбиения, пока в каждом листе не будет достигнуто $ n_min $ объектов или пока не достигнем определённой глубины дерева.
#
#         1) Выбрать $ m \leq p $ переменных случайным образом из $ p $ переменных.
#
#         2) Найти оптимальное разделение по $ m $ переменным.
#
#         3) Добавить разделение для найденного оптимального решения.
# 2. Итог - ансамбль деревьев $ \{ T_b \}^1_B $.
#
# <hr style="height:3px">
#
# Для предсказания модели на новых данных $x$:
# * Регрессия: $\large \hat{f}_{rf}^B(x) = \dfrac{1}{B} \sum_{b=1}^{B}T_b(x)$.
# * Классификация: пусть $\hat{C}_b(x)$ предсказания класса на $ b $-ом дереве случайного леса, тогда $ \large \hat{C}_{rf}^{B}(x) = majority\;vote \{ \hat{C}(x) \}_1^{B} $.
#
# При использовании бэггинга в случае, если переменная распределена i.i.d. (independently and identically distributed) разброс $Var$ уменьшается в $\dfrac{1}{B}$, где $B$ — количество деревьев. В случае наличия попарной корреляции между признаками $\rho$, среднее значение разброса принимает значение:
#
# $$ \large Var_\rho = \rho\sigma^2 + \dfrac{1-\rho}{B}\sigma^2 $$.
#
# По мере увеличения $B$ вторая компонента уменьшается, но первая компонента остается и зависит от коэффициента корреляции $\rho$. В предельном случае значение $\rho$ и будет определять допустимое значение разброса $Var$.
#
# При построении каждого дерева из случайного леса  какое случайное значение признаков $m$ стоит выбрать?
# Практика показала, что оптимальными значениями являются $m = \sqrt{p}$ для классификации и $ m=\dfrac{p}{3}$.
#
# В случае регрессии случайный лес $ \left\{ T(x; \Theta_b) \right\}^B_1$ ($\Theta_b $ - параметры $b$-го дерева) предсказание случайного леса определяется следующим выражением:
#
# $$ \hat{f}_{rf}^B(x) = \dfrac{1}{B} \sum_{b=1}^{B} T(x;\Theta_b) $$.
#
# Логично ожидать, что при уменьшении $ m $ в случае наличии корреляции в данных корреляция между деревьями будет уменьшаться и, тем самым, снижаться средний разброс. Среди дерьевев решений коэффициент корреляции обычно принимается равным $\rho(x) = 0.05 $.
#
# Такое рассуждение работает не для всех моделей при построении бэггиннга. Лучше всего это работает на сложных моделях, т.е. моделях с низким смещением $Bias$ и высоким $Variance$. В случае линейных моделей попарный коэффициент корреляции достигает значений $50\%$.

# %% [markdown]
# Давайте посмотрим на процесс обучения с точки зрения валидации и тестирования данных.
# Одной из характеристик случайного леса во время обучения является наличие Out-Of-Bag (OOB) ошибки: *для каждого примера $z_i = (x_i, y_i) $ построенная модель случайного леса будет предсказывать усредненем только те данные, которые не содержаться в бутстрэп выборке $z_i$.* OOB ошибка по смыслу близка к $N-fold$ кросс-валидации. В отличие от традиционных подходов, случайный лес при построении обучается с использованием кросс-валидации. Во время обучения стабилизации OOB ошибки позволяет оценить качество во время обучения и момент остановки процесса обучения.

# %% [markdown]
# Рассмотрим реализацию `RandomForestRegressor` в библиотеке [scikit-learn](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html) на примере предсказания стоимости недвиджимости в датасете [House Sales](https://www.kaggle.com/harlfoxem/housesalesprediction).

# %%
# import model class
from sklearn.ensemble import RandomForestRegressor

# %%
# import dataset
df = pd.read_csv('./dataset/kc_house_data.csv', index_col='id')

# %%
# see the dataset 
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 7129300520              0      1955             0    98178  47.5112 -122.257
# 6414100192            400      1951          1991    98125  47.7210 -122.319
# 5631500400              0      1933             0    98028  47.7379 -122.233
# 2487200875            910      1965             0    98136  47.5208 -122.393
# 1954400510              0      1987             0    98074  47.6168 -122.045
#
#             sqft_living15  sqft_lot15
# id
# 7129300520           1340        5650
# 6414100192           1690        7639
# 5631500400           2720        8062
# 2487200875           1360        5000
# 1954400510           1800        7503

# %%
# create targets - price and remove data for simplifying and price from dataset
y = df['price']
df = df.drop(['price', 'date'], axis=1)

# %%
# see corrected dataset
df.head()
# Out:
#             bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# id
# 7129300520         3       1.00         1180      5650     1.0           0
# 6414100192         3       2.25         2570      7242     2.0           0
# 5631500400         2       1.00          770     10000     1.0           0
# 2487200875         4       3.00         1960      5000     1.0           0
# 1954400510         3       2.00         1680      8080     1.0           0
#
#             view  condition  grade  sqft_above  sqft_basement  yr_built  \
# id
# 7129300520     0          3      7        1180              0      1955
# 6414100192     0          3      7        2170            400      1951
# 5631500400     0          3      6         770              0      1933
# 2487200875     0          5      7        1050            910      1965
# 1954400510     0          3      8        1680              0      1987
#
#             yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# id
# 7129300520             0    98178  47.5112 -122.257           1340        5650
# 6414100192          1991    98125  47.7210 -122.319           1690        7639
# 5631500400             0    98028  47.7379 -122.233           2720        8062
# 2487200875             0    98136  47.5208 -122.393           1360        5000
# 1954400510             0    98074  47.6168 -122.045           1800        7503

# %% [markdown]
# Инициализируем модель:

# %%
rf = RandomForestRegressor(oob_score=True)

# %% [markdown]
# И обучим её на данных, присваивая разное количество деревьев:

# %%
min_estimators = 2
max_estimators = 30
oob_errors = []
for i in range(min_estimators, max_estimators + 1):
    print('Fit with {} estimators..'.format(i))
    rf.set_params(n_estimators=i)
    rf.fit(df, y)
    
    # Record the OOB error for each `n_estimators=i` setting.
    oob_error = 1 - rf.oob_score_
    oob_errors.append((i, oob_error))
oob_errors = np.array(oob_errors)
# Out:
# Fit with 2 estimators..
# f:\venvs\fil\lib\site-packages\sklearn\ensemble\forest.py:732: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# Fit with 3 estimators..
# f:\venvs\fil\lib\site-packages\sklearn\ensemble\forest.py:732: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# Fit with 4 estimators..
# f:\venvs\fil\lib\site-packages\sklearn\ensemble\forest.py:732: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# Fit with 5 estimators..
# f:\venvs\fil\lib\site-packages\sklearn\ensemble\forest.py:732: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# Fit with 6 estimators..
# f:\venvs\fil\lib\site-packages\sklearn\ensemble\forest.py:732: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# Fit with 7 estimators..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-e0b33f5838f7> in <module>
#       5     print('Fit with {} estimators..'.format(i))
#       6     rf.set_params(n_estimators=i)
# ----> 7     rf.fit(df, y)
#       8
#       9     # Record the OOB error for each `n_estimators=i` setting.
#
# f:\venvs\fil\lib\site-packages\sklearn\ensemble\forest.py in fit(self, X, y, sample_weight)
#     331                     t, self, X, y, sample_weight, i, len(trees),
#     332                     verbose=self.verbose, class_weight=self.class_weight)
# --> 333                 for i, t in enumerate(trees))
#     334
#     335             # Collect newly grown trees
#
# f:\venvs\fil\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# f:\venvs\fil\lib\site-packages\sklearn\externals\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# f:\venvs\fil\lib\site-packages\sklearn\externals\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# f:\venvs\fil\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# f:\venvs\fil\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# f:\venvs\fil\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# f:\venvs\fil\lib\site-packages\sklearn\externals\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# f:\venvs\fil\lib\site-packages\sklearn\ensemble\forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight)
#     117             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     118
# --> 119         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     120     else:
#     121         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# f:\venvs\fil\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1140             sample_weight=sample_weight,
#    1141             check_input=check_input,
# -> 1142             X_idx_sorted=X_idx_sorted)
#    1143         return self
#    1144
#
# f:\venvs\fil\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     364                                            min_impurity_split)
#     365
# --> 366         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     367
#     368         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %% [markdown]
# Визуализируем OOB ошибку от количества деревьев:

# %%
plt.xkcd()
plt.figure(figsize=(9,7))
oob_errors = np.array(oob_errors)
plt.plot(oob_errors[:, 0], oob_errors[:, 1])
plt.grid()
_ = plt.xlabel('n_estimators')
_ = plt.ylabel('OOB error')
# Out:
# <img src="data:image/png;base64,..." width="900">

# %% [markdown]
# На практике OOB ошибка всегда будет иметь более оптимистичное значение.
#
# Признаки, позволяющие более качественно проводить разбиения в каждом дереве, могут быть оценены для последующего анализа модели. Для этого учитывается каждое из разбиений и по какому признаку оно выполняется.

# %%
features = df.columns
importances = rf.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(9, 7))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='g', align='center')
_ = plt.yticks(range(len(indices)), [features[i] for i in indices])
_ = plt.xlabel('Relative Importance')
_ = plt.grid()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-24-79018acd1ac0> in <module>
#       1 features = df.columns
# ----> 2 importances = rf.feature_importances_
#       3 indices = np.argsort(importances)
#       4
#       5 plt.figure(figsize=(9, 7))
#
# f:\venvs\fil\lib\site-packages\sklearn\ensemble\forest.py in feature_importances_(self)
#     378             for tree in self.estimators_)
#     379
# --> 380         return sum(all_importances) / len(self.estimators_)
#     381
#     382
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Плюсы:
# * обладает хорошим качеством: на большинстве задач лучше линейных моделей, а точность сравнима с точностью бустинга
# * не чувствителен к выбросам из-за случайного сэмплирования данных
# * отсутствие требований к предобработке данных
# * Out-of-bag ошибка
# * небольшая чувствительность к гиперпараметрам, то есть даёт качественный результат прямо из коробки
# * способен эффективно обрабатывать данные с большим числом признаков и классов
# * одинаково хорошо обрабатывет как непрерывные, так и дискретные признаки
# * редко переобучается, на практике добавление деревьев почти всегда только улучшает композицию, но на валидации, после достижения определенного количества деревьев, кривая обучения выходит на асимптоту
# * для случайного леса существуют методы оценивания значимости отдельных признаков в модели
# * хорошо работает с пропущенными данными; сохраняет хорошую точность, если большая часть данных пропущенна
# * предполагает возможность сбалансировать вес каждого класса на всей выборке, либо на подвыборке каждого дерева
# * вычисляет близость между парами объектов (proximity plot), которые могут использоваться при кластеризации, обнаружении выбросов или (путем масштабирования) дают интересные представления данных
# * возможности, описанные выше, могут быть расширены до немаркированных данных, что приводит к возможноти делать кластеризацию и визуализацию данных, обнаруживать выбросы
# * высокая параллелизуемость и масштабируемость
#
# Минусы:
# * не позволяет качественно интерпретировать зависимости
# * нет формальных выводов (p-values), доступных для оценки важности переменных
# * алгоритм работает хуже многих линейных методов, когда в выборке очень много разреженных признаков (тексты, Bag of words)
# * случайный лес не умеет экстраполировать, в отличие от той же линейной регрессии (но это можно считать и плюсом, так как не будет экстремальных значений в случае попадания выброса)
# * алгоритм склонен к переобучению на некоторых задачах, особенно на зашумленных данных
# * для данных, включающих категориальные переменные с различным количеством уровней, случайные леса предвзяты в пользу признаков с большим количеством уровней: когда у признака много уровней, дерево будет сильнее подстраиваться именно под эти признаки, так как на них можно получить более высокую точность
# * если данные содержат группы коррелированных признаков, имеющих схожую значимость для меток, то предпочтение отдается небольшим группам перед большими
# * больший размер получающихся моделей: требуется $\large O(NK)$ памяти для хранения модели, где $\large K $ — число деревьев

# %% [markdown]
# # <center> Бустинг </center>
#
# *«When in doubt – use xgboost»
# Owen Zhang, top-2 on Kaggle.*
#
# Бустинг - одна из самых сильных идей в машинном обучении за последние 30 лет.
#
# Идея простая: используя модели, точность которых немногим выше случайного угадывания, построить сильную модель. Тогда можно записать результат работы такого представления:
#
# $$\large f(x) = \sum_{m=1}^{M}\beta_m\,b(x;\gamma_m), $$
#
# $ \beta_m, m=1, \ldots, M $ - коэффициенты для каждой из модели,
#
# $ b(x;\gamma) \in \mathbb{R} $ - функция, характеризуемая параметрами $\gamma$.
#
#
#
# Одной из первых реализованных моделей бустинга была модель [AdaBoost.M1](https://web.eecs.utk.edu/~leparker/Courses/CS425-528-fall10/Handouts/AdaBoost.M1.pdf).
#
# <hr style="height:3px">
#
# **Алгоритм AdaBoost.M1**
#
# <hr style="height:3px">
#
# Опишем её более формально:
# 1. Инициализируем веса для каждого из примера в выборке $w_i = \dfrac{1}{N}, i = 1,\,2,\ldots, N$.
# 2. Для m=1 до M:
#     a. Обучить классификатор $G_m(x)$ на обучающей выборке используя веса $w_i$.
#     b. Вычислить ошибку
#
#     $$ \large err_m = \dfrac{\sum_{i=1}^{N} w_i I(y_i \neq G_m(x_i))}{\sum_{i=1}^{N} w_i} $$
#
#     c. Вычислить $\large \alpha_m = \log \left( \dfrac{1-err_m}{err_m} \right) $
#
#     d. $ \large w_i \leftarrow w_i * exp[\alpha_m * I(y_i \neq G_m(x_i)], i = 1, 2, \ldots, N  $
#
# 3. Выход:
# $$ \large G(x) = sign\left[ \sum_{m=1}^{M} \alpha_m G_m(x) \right] $$
#
# <hr style="height:3px">
#
#
# Рассмотрим функцию ошибки, которую пытается минимизировать классификатор:
#
# $$\large \overline{err} = \dfrac{1}{N} \sum_{i=1}^{N} I (y_i \neq G(x_i)) $$
#
# Цель бустинга оптимизировать эту ошибку, последовательно обучая модель на перевзвешенных данных и добавляя модель к исходному ансамблю. Функция ошибки напрямую не является дифференцируемой. Вместо этого используют некоторую верхнюю оценку, т.е. аппроксимацию этой функции.
#
# Для различных аппроксимаций пороговой функции потерь $[z < 0]$ получаются различные виды бустинга:
# - $e^{-z}$ - AdaBoost
# - $\log_2(1 + e^{-z})$ - LogitBoost
# - $(1 - z)^2$ - GentleBoost
# - $e^{-cz(z+a)}$ - BrownBoost
# - другие

# %%
x = np.linspace(-2, 2, 500)

plt.figure(figsize=(9.5,6))
plt.plot(x, x < 0, lw=2, label='Threshold function: $[M < 0$]')
plt.plot(x, np.exp(-x), lw=2, label='AdaBoost')
plt.plot(x, np.log2(1 + np.exp(-x)), lw=2, label='LogitBoost')
plt.plot(x, (1 - x) ** 2, lw=2, label='GentleBoost')
plt.plot(x, np.exp(-x * (x + 2)), lw=2, label='BrownBoost')
plt.title('Various approximations of the threshold function')
plt.legend(loc='best')
plt.xlabel('Margin')
plt.ylabel('Loss');
# Out:
# <img src="data:image/png;base64,..." width="950">

# %% [markdown]
# Проиллюстрируем пример работы AdaBoost на игрушечном примере с использованием деревьев решений:
#
# <img src="images/adaboost.png">
#
# Алгоритм бустинга в общем смысле пытается минимизировать некоторую функцию потерь, определяемую в общем случае выражением:
#
# $$ \Large \min_{\{\beta_m, \gamma_m\}_1^M} \sum_{i=1}^{N} L \left( y_i, \sum_{m=1}^{M} \beta_m b(x_i;\gamma_m) \right) $$.
#
# Но для многих функций потерь оптимизация по параметрам модели для всех моделей композиции является вычислительно затратной, поэтому вместо общей функции потерь используют оптимизацию функции с моделью при её добавлении:
#
# $$ \Large \min_{\beta, \gamma} \sum_{i=1}^{N} L \left( y_i, \beta b(x_i; \, \gamma) \right) $$.
#
# В таком случае алгоритм бустинга описывает последовательно добавление функций с оптимизируемыми параметрами к ансамблю моделей с фиксированными параметрами:
#
# <hr style="height:3px">
#
# **Алгоритм Forward Stagewise Additive Modeling**
#
# <hr style="height:3px">
#
# 1. Инициализиурем функцию $f_0(x) = 0$
# 2. Для $m = 1, ..., \ldots M$:
#
#     a. Вычислить:
#
#     $$\Large (\beta_m, \gamma_m) = \arg \, \min_{\beta, \gamma} \sum_{i=1}^{N} L(y_i, f_{m-1} (x_i) + \beta\,b(x_i, \gamma)) $$.
#
#     b. Присвоить:
#     $$ \Large f_m(x) = f_{m-1}(x) + \beta_m b(x; \gamma_m) $$
#
# <hr style="height:3px">
#
# Для квадратичной функции потерь $ L(y, f(x)) = (y-f(x))^2 $:
#
# $$\Large L(y_i, f_{m-1}(x_i) + \beta\,b(x_i, \gamma)) = (y_i - f_{m-1}(x_i) - \beta\, b(x_i; \gamma))^2 = (r_{im} - \beta\,b(x_i;\gamma))^2 $$,
#
# $ r_{im} = y_i - f_{m-1}(x_i) $ - остатки, то есть разница между текущим ансамблем и $i$-м наблюдением

# %% [markdown]
# <img src="images/adaboost.gif">

# %% [markdown]
# **Обучим модель XGBoost Regressor на данных по предсказанию цены**

# %% [markdown]
# Посмотрим на данные еще раз, чтобы убедиться в их правильности:

# %%
df.head()
# Out:
#             bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# id
# 7129300520         3       1.00         1180      5650     1.0           0
# 6414100192         3       2.25         2570      7242     2.0           0
# 5631500400         2       1.00          770     10000     1.0           0
# 2487200875         4       3.00         1960      5000     1.0           0
# 1954400510         3       2.00         1680      8080     1.0           0
#
#             view  condition  grade  sqft_above  sqft_basement  yr_built  \
# id
# 7129300520     0          3      7        1180              0      1955
# 6414100192     0          3      7        2170            400      1951
# 5631500400     0          3      6         770              0      1933
# 2487200875     0          5      7        1050            910      1965
# 1954400510     0          3      8        1680              0      1987
#
#             yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# id
# 7129300520             0    98178  47.5112 -122.257           1340        5650
# 6414100192          1991    98125  47.7210 -122.319           1690        7639
# 5631500400             0    98028  47.7379 -122.233           2720        8062
# 2487200875             0    98136  47.5208 -122.393           1360        5000
# 1954400510             0    98074  47.6168 -122.045           1800        7503

# %%
y[:5]
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
# Name: price, dtype: float64

# %% [markdown]
# [Поделим](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) выборку на обучающую и тестовую в соотношении 70/30:

# %%
X_train, X_test, y_train, y_test = train_test_split(df, y, random_state=17)

# %%
X_train

# %% [markdown]
# Импортируем xgboost

# %% [markdown]
# Импортируем XGBoost модель из библиотеки. Существует несколько вариантов использования XGBoost: на Python распространены [обёртка](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html) под библиотеку Scikit-Learn и исходный интерфейс к XGBoost.

# %%
import xgboost as xgb

# %%
params = {
    'objective': 'reg:linear',
    'max_depth': 15,
    'learning_rate': 0.1,
#     'silent': 0.0,
    'n_estimators': 500,
}
num_rounds = 1000

# %%
xgb_model = xgb.XGBRegressor(**params)

# %%
# use native interface
dtrain = xgb.DMatrix(X_train, y_train)
dtest = xgb.DMatrix(X_test, y_test)

# %%
# see error for train and test examples due training
watchlist  = [(dtest,'test'), (dtrain,'train')]

# %%
xgb_model = xgb.train(params, dtrain, num_rounds, watchlist)
# Out:
# [09:26:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 0 pruned nodes, max_depth=14
# [0]	test-rmse:605400	train-rmse:588107
# [09:26:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 558 extra nodes, 0 pruned nodes, max_depth=15
# [1]	test-rmse:551298	train-rmse:533644
# [09:26:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 604 extra nodes, 0 pruned nodes, max_depth=15
# [2]	test-rmse:502899	train-rmse:484570
# [09:26:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 702 extra nodes, 0 pruned nodes, max_depth=15
# [3]	test-rmse:458917	train-rmse:440394
# [09:26:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 794 extra nodes, 0 pruned nodes, max_depth=15
# [4]	test-rmse:419616	train-rmse:400463
# [09:26:08] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 986 extra nodes, 0 pruned nodes, max_depth=15
# [5]	test-rmse:385707	train-rmse:364534
# [09:26:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1126 extra nodes, 0 pruned nodes, max_depth=15
# [6]	test-rmse:355234	train-rmse:332117
# [09:26:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1278 extra nodes, 0 pruned nodes, max_depth=15
# [7]	test-rmse:327666	train-rmse:302744
# [09:26:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1574 extra nodes, 0 pruned nodes, max_depth=15
# [8]	test-rmse:302851	train-rmse:276354
# [09:26:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1758 extra nodes, 0 pruned nodes, max_depth=15
# [9]	test-rmse:281022	train-rmse:252440
# [09:26:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1838 extra nodes, 0 pruned nodes, max_depth=15
# [10]	test-rmse:261756	train-rmse:230792
# [09:26:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2222 extra nodes, 0 pruned nodes, max_depth=15
# [11]	test-rmse:245525	train-rmse:211239
# [09:26:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2200 extra nodes, 0 pruned nodes, max_depth=15
# [12]	test-rmse:230557	train-rmse:193518
# [09:26:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2360 extra nodes, 0 pruned nodes, max_depth=15
# [13]	test-rmse:217568	train-rmse:177456
# [09:26:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2568 extra nodes, 0 pruned nodes, max_depth=15
# [14]	test-rmse:205810	train-rmse:162887
# [09:26:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2730 extra nodes, 0 pruned nodes, max_depth=15
# [15]	test-rmse:195751	train-rmse:149707
# [09:26:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3094 extra nodes, 0 pruned nodes, max_depth=15
# [16]	test-rmse:187159	train-rmse:137635
# [09:26:09] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3078 extra nodes, 0 pruned nodes, max_depth=15
# [17]	test-rmse:179685	train-rmse:126802
# [09:26:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3274 extra nodes, 0 pruned nodes, max_depth=15
# [18]	test-rmse:173187	train-rmse:116919
# [09:26:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3308 extra nodes, 0 pruned nodes, max_depth=15
# [19]	test-rmse:167672	train-rmse:107921
# [09:26:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3580 extra nodes, 0 pruned nodes, max_depth=15
# [20]	test-rmse:162710	train-rmse:99733.7
# [09:26:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3238 extra nodes, 0 pruned nodes, max_depth=15
# [21]	test-rmse:158448	train-rmse:92320.1
# [09:26:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3666 extra nodes, 0 pruned nodes, max_depth=15
# [22]	test-rmse:154862	train-rmse:85558.9
# [09:26:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3730 extra nodes, 0 pruned nodes, max_depth=15
# [23]	test-rmse:151573	train-rmse:79426.4
# [09:26:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3654 extra nodes, 0 pruned nodes, max_depth=15
# [24]	test-rmse:148786	train-rmse:73853.5
# [09:26:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3662 extra nodes, 0 pruned nodes, max_depth=15
# [25]	test-rmse:146531	train-rmse:68821
# [09:26:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4078 extra nodes, 0 pruned nodes, max_depth=15
# [26]	test-rmse:144663	train-rmse:64153.3
# [09:26:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3222 extra nodes, 0 pruned nodes, max_depth=15
# [27]	test-rmse:142768	train-rmse:60010.7
# [09:26:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3768 extra nodes, 0 pruned nodes, max_depth=15
# [28]	test-rmse:141440	train-rmse:56225.5
# [09:26:10] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3892 extra nodes, 0 pruned nodes, max_depth=15
# [29]	test-rmse:140172	train-rmse:52786.6
# [09:26:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4188 extra nodes, 0 pruned nodes, max_depth=15
# [30]	test-rmse:139049	train-rmse:49599.9
# [09:26:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3444 extra nodes, 0 pruned nodes, max_depth=15
# [31]	test-rmse:137927	train-rmse:46810.5
# [09:26:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3992 extra nodes, 0 pruned nodes, max_depth=15
# [32]	test-rmse:137269	train-rmse:44242.1
# [09:26:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4044 extra nodes, 0 pruned nodes, max_depth=15
# [33]	test-rmse:136497	train-rmse:41851.6
# [09:26:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4050 extra nodes, 0 pruned nodes, max_depth=15
# [34]	test-rmse:135745	train-rmse:39620.3
# [09:26:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4262 extra nodes, 0 pruned nodes, max_depth=15
# [35]	test-rmse:135061	train-rmse:37545.3
# [09:26:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4224 extra nodes, 0 pruned nodes, max_depth=15
# [36]	test-rmse:134442	train-rmse:35698.1
# [09:26:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4062 extra nodes, 0 pruned nodes, max_depth=15
# [37]	test-rmse:133936	train-rmse:34069.2
# [09:26:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4004 extra nodes, 0 pruned nodes, max_depth=15
# [38]	test-rmse:133543	train-rmse:32634.4
# [09:26:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3532 extra nodes, 0 pruned nodes, max_depth=15
# [39]	test-rmse:133185	train-rmse:31304
# [09:26:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4278 extra nodes, 0 pruned nodes, max_depth=15
# [40]	test-rmse:132808	train-rmse:29991.2
# [09:26:11] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4414 extra nodes, 0 pruned nodes, max_depth=15
# [41]	test-rmse:132462	train-rmse:28765.3
# [09:26:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4074 extra nodes, 0 pruned nodes, max_depth=15
# [42]	test-rmse:132185	train-rmse:27696.9
# [09:26:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3782 extra nodes, 0 pruned nodes, max_depth=15
# [43]	test-rmse:131939	train-rmse:26697.7
# [09:26:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3542 extra nodes, 0 pruned nodes, max_depth=15
# [44]	test-rmse:131750	train-rmse:25855.5
# [09:26:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3728 extra nodes, 0 pruned nodes, max_depth=15
# [45]	test-rmse:131599	train-rmse:25063.1
# [09:26:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3728 extra nodes, 0 pruned nodes, max_depth=15
# [46]	test-rmse:131415	train-rmse:24345.9
# [09:26:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3410 extra nodes, 0 pruned nodes, max_depth=15
# [47]	test-rmse:131273	train-rmse:23719.1
# [09:26:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3828 extra nodes, 0 pruned nodes, max_depth=15
# [48]	test-rmse:131140	train-rmse:23101.4
# [09:26:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3390 extra nodes, 0 pruned nodes, max_depth=15
# [49]	test-rmse:131038	train-rmse:22614
# [09:26:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3686 extra nodes, 0 pruned nodes, max_depth=15
# [50]	test-rmse:130914	train-rmse:22017
# [09:26:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3290 extra nodes, 0 pruned nodes, max_depth=15
# [51]	test-rmse:130808	train-rmse:21580.1
# [09:26:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3084 extra nodes, 0 pruned nodes, max_depth=15
# [52]	test-rmse:130727	train-rmse:21169
# [09:26:12] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2508 extra nodes, 0 pruned nodes, max_depth=15
# [53]	test-rmse:130635	train-rmse:20843
# [09:26:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2570 extra nodes, 0 pruned nodes, max_depth=15
# [54]	test-rmse:130585	train-rmse:20502.2
# [09:26:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2792 extra nodes, 0 pruned nodes, max_depth=15
# [55]	test-rmse:130523	train-rmse:20134.3
# [09:26:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2722 extra nodes, 0 pruned nodes, max_depth=15
# [56]	test-rmse:130479	train-rmse:19795.5
# [09:26:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2582 extra nodes, 0 pruned nodes, max_depth=15
# [57]	test-rmse:130442	train-rmse:19448.1
# [09:26:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2672 extra nodes, 0 pruned nodes, max_depth=15
# [58]	test-rmse:130379	train-rmse:19185.2
# [09:26:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2910 extra nodes, 0 pruned nodes, max_depth=15
# [59]	test-rmse:130307	train-rmse:18988.4
# [09:26:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2742 extra nodes, 0 pruned nodes, max_depth=15
# [60]	test-rmse:130249	train-rmse:18807.7
# [09:26:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2190 extra nodes, 0 pruned nodes, max_depth=15
# [61]	test-rmse:130208	train-rmse:18640.6
# [09:26:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2852 extra nodes, 0 pruned nodes, max_depth=15
# [62]	test-rmse:130150	train-rmse:18426.7
# [09:26:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2886 extra nodes, 0 pruned nodes, max_depth=15
# [63]	test-rmse:130101	train-rmse:18227.9
# [09:26:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2964 extra nodes, 0 pruned nodes, max_depth=15
# [64]	test-rmse:130082	train-rmse:18011.3
# [09:26:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2066 extra nodes, 0 pruned nodes, max_depth=15
# [65]	test-rmse:130061	train-rmse:17914.5
# [09:26:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3162 extra nodes, 0 pruned nodes, max_depth=15
# [66]	test-rmse:130038	train-rmse:17726.7
# [09:26:13] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2116 extra nodes, 0 pruned nodes, max_depth=15
# [67]	test-rmse:130020	train-rmse:17589.1
# [09:26:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2382 extra nodes, 0 pruned nodes, max_depth=15
# [68]	test-rmse:130010	train-rmse:17463.1
# [09:26:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2204 extra nodes, 0 pruned nodes, max_depth=15
# [69]	test-rmse:129987	train-rmse:17348.4
# [09:26:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2150 extra nodes, 0 pruned nodes, max_depth=15
# [70]	test-rmse:129968	train-rmse:17225.5
# [09:26:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2294 extra nodes, 0 pruned nodes, max_depth=15
# [71]	test-rmse:129957	train-rmse:17055.5
# [09:26:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1992 extra nodes, 0 pruned nodes, max_depth=15
# [72]	test-rmse:129939	train-rmse:16998.5
# [09:26:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2042 extra nodes, 0 pruned nodes, max_depth=15
# [73]	test-rmse:129927	train-rmse:16921.8
# [09:26:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2774 extra nodes, 0 pruned nodes, max_depth=15
# [74]	test-rmse:129919	train-rmse:16676.3
# [09:26:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1908 extra nodes, 0 pruned nodes, max_depth=15
# [75]	test-rmse:129904	train-rmse:16632.1
# [09:26:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1922 extra nodes, 0 pruned nodes, max_depth=15
# [76]	test-rmse:129896	train-rmse:16582.2
# [09:26:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2636 extra nodes, 0 pruned nodes, max_depth=15
# [77]	test-rmse:129889	train-rmse:16410.9
# [09:26:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3020 extra nodes, 0 pruned nodes, max_depth=15
# [78]	test-rmse:129873	train-rmse:16270
# [09:26:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2864 extra nodes, 0 pruned nodes, max_depth=15
# [79]	test-rmse:129860	train-rmse:16118.3
# [09:26:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1562 extra nodes, 0 pruned nodes, max_depth=15
# [80]	test-rmse:129854	train-rmse:16049.9
# [09:26:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1976 extra nodes, 0 pruned nodes, max_depth=15
# [81]	test-rmse:129845	train-rmse:15968.7
# [09:26:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1164 extra nodes, 0 pruned nodes, max_depth=15
# [82]	test-rmse:129839	train-rmse:15946.4
# [09:26:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1850 extra nodes, 0 pruned nodes, max_depth=15
# [83]	test-rmse:129836	train-rmse:15752.9
# [09:26:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1712 extra nodes, 0 pruned nodes, max_depth=15
# [84]	test-rmse:129834	train-rmse:15669.1
# [09:26:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1494 extra nodes, 0 pruned nodes, max_depth=15
# [85]	test-rmse:129829	train-rmse:15601.7
# [09:26:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1518 extra nodes, 0 pruned nodes, max_depth=15
# [86]	test-rmse:129827	train-rmse:15557.2
# [09:26:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1592 extra nodes, 0 pruned nodes, max_depth=15
# [87]	test-rmse:129833	train-rmse:15434.8
# [09:26:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 982 extra nodes, 0 pruned nodes, max_depth=15
# [88]	test-rmse:129832	train-rmse:15393.2
# [09:26:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2450 extra nodes, 0 pruned nodes, max_depth=15
# [89]	test-rmse:129834	train-rmse:15240.9
# [09:26:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1278 extra nodes, 0 pruned nodes, max_depth=15
# [90]	test-rmse:129837	train-rmse:15124.3
# [09:26:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1900 extra nodes, 0 pruned nodes, max_depth=15
# [91]	test-rmse:129828	train-rmse:15013.4
# [09:26:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 872 extra nodes, 0 pruned nodes, max_depth=15
# [92]	test-rmse:129826	train-rmse:14956.3
# [09:26:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2002 extra nodes, 0 pruned nodes, max_depth=15
# [93]	test-rmse:129821	train-rmse:14869.2
# [09:26:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1074 extra nodes, 0 pruned nodes, max_depth=15
# [94]	test-rmse:129815	train-rmse:14827.5
# [09:26:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2068 extra nodes, 0 pruned nodes, max_depth=15
# [95]	test-rmse:129820	train-rmse:14704.4
# [09:26:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1602 extra nodes, 0 pruned nodes, max_depth=15
# [96]	test-rmse:129823	train-rmse:14620
# [09:26:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1988 extra nodes, 0 pruned nodes, max_depth=15
# [97]	test-rmse:129814	train-rmse:14551.1
# [09:26:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1332 extra nodes, 0 pruned nodes, max_depth=15
# [98]	test-rmse:129806	train-rmse:14450.3
# [09:26:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2074 extra nodes, 0 pruned nodes, max_depth=15
# [99]	test-rmse:129809	train-rmse:14375.6
# [09:26:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1562 extra nodes, 0 pruned nodes, max_depth=15
# [100]	test-rmse:129811	train-rmse:14293.8
# [09:26:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1338 extra nodes, 0 pruned nodes, max_depth=15
# [101]	test-rmse:129814	train-rmse:14209.6
# [09:26:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2220 extra nodes, 0 pruned nodes, max_depth=15
# [102]	test-rmse:129814	train-rmse:14087.3
# [09:26:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1512 extra nodes, 0 pruned nodes, max_depth=15
# [103]	test-rmse:129815	train-rmse:14040.6
# [09:26:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1618 extra nodes, 0 pruned nodes, max_depth=15
# [104]	test-rmse:129813	train-rmse:13950.6
# [09:26:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1596 extra nodes, 0 pruned nodes, max_depth=15
# [105]	test-rmse:129816	train-rmse:13867.5
# [09:26:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2150 extra nodes, 0 pruned nodes, max_depth=15
# [106]	test-rmse:129821	train-rmse:13768.3
# [09:26:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1630 extra nodes, 0 pruned nodes, max_depth=15
# [107]	test-rmse:129827	train-rmse:13672.1
# [09:26:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2712 extra nodes, 0 pruned nodes, max_depth=15
# [108]	test-rmse:129839	train-rmse:13495.5
# [09:26:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2206 extra nodes, 0 pruned nodes, max_depth=15
# [109]	test-rmse:129841	train-rmse:13370.1
# [09:26:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2378 extra nodes, 0 pruned nodes, max_depth=15
# [110]	test-rmse:129844	train-rmse:13238.2
# [09:26:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1172 extra nodes, 0 pruned nodes, max_depth=15
# [111]	test-rmse:129845	train-rmse:13207.6
# [09:26:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1398 extra nodes, 0 pruned nodes, max_depth=15
# [112]	test-rmse:129845	train-rmse:13168.3
# [09:26:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2072 extra nodes, 0 pruned nodes, max_depth=15
# [113]	test-rmse:129848	train-rmse:13080.7
# [09:26:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3844 extra nodes, 0 pruned nodes, max_depth=15
# [114]	test-rmse:129852	train-rmse:12877
# [09:26:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3766 extra nodes, 0 pruned nodes, max_depth=15
# [115]	test-rmse:129854	train-rmse:12699.5
# [09:26:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2880 extra nodes, 0 pruned nodes, max_depth=15
# [116]	test-rmse:129852	train-rmse:12571.2
# [09:26:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 826 extra nodes, 0 pruned nodes, max_depth=15
# [117]	test-rmse:129851	train-rmse:12543.5
# [09:26:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1634 extra nodes, 0 pruned nodes, max_depth=15
# [118]	test-rmse:129852	train-rmse:12474
# [09:26:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2942 extra nodes, 0 pruned nodes, max_depth=15
# [119]	test-rmse:129857	train-rmse:12356.9
# [09:26:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 676 extra nodes, 0 pruned nodes, max_depth=15
# [120]	test-rmse:129856	train-rmse:12338.8
# [09:26:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2352 extra nodes, 0 pruned nodes, max_depth=15
# [121]	test-rmse:129861	train-rmse:12266.1
# [09:26:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3302 extra nodes, 0 pruned nodes, max_depth=15
# [122]	test-rmse:129869	train-rmse:12142.6
# [09:26:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1522 extra nodes, 0 pruned nodes, max_depth=15
# [123]	test-rmse:129866	train-rmse:12082.5
# [09:26:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2574 extra nodes, 0 pruned nodes, max_depth=15
# [124]	test-rmse:129870	train-rmse:12007.9
# [09:26:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3032 extra nodes, 0 pruned nodes, max_depth=15
# [125]	test-rmse:129869	train-rmse:11904.9
# [09:26:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2168 extra nodes, 0 pruned nodes, max_depth=15
# [126]	test-rmse:129871	train-rmse:11862.4
# [09:26:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1196 extra nodes, 0 pruned nodes, max_depth=15
# [127]	test-rmse:129871	train-rmse:11837.9
# [09:26:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1042 extra nodes, 0 pruned nodes, max_depth=15
# [128]	test-rmse:129871	train-rmse:11823.6
# [09:26:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2886 extra nodes, 0 pruned nodes, max_depth=15
# [129]	test-rmse:129867	train-rmse:11766.6
# [09:26:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2600 extra nodes, 0 pruned nodes, max_depth=15
# [130]	test-rmse:129874	train-rmse:11702.3
# [09:26:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1656 extra nodes, 0 pruned nodes, max_depth=15
# [131]	test-rmse:129875	train-rmse:11673.9
# [09:26:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3266 extra nodes, 0 pruned nodes, max_depth=15
# [132]	test-rmse:129880	train-rmse:11582.9
# [09:26:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3010 extra nodes, 0 pruned nodes, max_depth=15
# [133]	test-rmse:129886	train-rmse:11498
# [09:26:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2914 extra nodes, 0 pruned nodes, max_depth=15
# [134]	test-rmse:129891	train-rmse:11421.7
# [09:26:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3136 extra nodes, 0 pruned nodes, max_depth=15
# [135]	test-rmse:129893	train-rmse:11341.6
# [09:26:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1918 extra nodes, 0 pruned nodes, max_depth=15
# [136]	test-rmse:129895	train-rmse:11309.5
# [09:26:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1786 extra nodes, 0 pruned nodes, max_depth=15
# [137]	test-rmse:129894	train-rmse:11285.2
# [09:26:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2910 extra nodes, 0 pruned nodes, max_depth=15
# [138]	test-rmse:129898	train-rmse:11226.5
# [09:26:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1700 extra nodes, 0 pruned nodes, max_depth=15
# [139]	test-rmse:129900	train-rmse:11178.3
# [09:26:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1780 extra nodes, 0 pruned nodes, max_depth=15
# [140]	test-rmse:129900	train-rmse:11152.7
# [09:26:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1240 extra nodes, 0 pruned nodes, max_depth=15
# [141]	test-rmse:129900	train-rmse:11142.9
# [09:26:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2200 extra nodes, 0 pruned nodes, max_depth=15
# [142]	test-rmse:129895	train-rmse:11120.8
# [09:26:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3510 extra nodes, 0 pruned nodes, max_depth=15
# [143]	test-rmse:129896	train-rmse:11044.4
# [09:26:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 850 extra nodes, 0 pruned nodes, max_depth=15
# [144]	test-rmse:129898	train-rmse:11024.3
# [09:26:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2034 extra nodes, 0 pruned nodes, max_depth=15
# [145]	test-rmse:129901	train-rmse:10986.7
# [09:26:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1088 extra nodes, 0 pruned nodes, max_depth=15
# [146]	test-rmse:129900	train-rmse:10974
# [09:26:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3422 extra nodes, 0 pruned nodes, max_depth=15
# [147]	test-rmse:129902	train-rmse:10902
# [09:26:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 792 extra nodes, 0 pruned nodes, max_depth=15
# [148]	test-rmse:129902	train-rmse:10893.9
# [09:26:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 900 extra nodes, 0 pruned nodes, max_depth=15
# [149]	test-rmse:129904	train-rmse:10881.2
# [09:26:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2414 extra nodes, 0 pruned nodes, max_depth=15
# [150]	test-rmse:129905	train-rmse:10850.9
# [09:26:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2352 extra nodes, 0 pruned nodes, max_depth=15
# [151]	test-rmse:129906	train-rmse:10805.1
# [09:26:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1762 extra nodes, 0 pruned nodes, max_depth=15
# [152]	test-rmse:129908	train-rmse:10769.6
# [09:26:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1960 extra nodes, 0 pruned nodes, max_depth=15
# [153]	test-rmse:129909	train-rmse:10727.2
# [09:26:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2066 extra nodes, 0 pruned nodes, max_depth=15
# [154]	test-rmse:129912	train-rmse:10678.1
# [09:26:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1872 extra nodes, 0 pruned nodes, max_depth=15
# [155]	test-rmse:129915	train-rmse:10646.4
# [09:26:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1642 extra nodes, 0 pruned nodes, max_depth=15
# [156]	test-rmse:129913	train-rmse:10624.1
# [09:26:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1590 extra nodes, 0 pruned nodes, max_depth=15
# [157]	test-rmse:129911	train-rmse:10613.7
# [09:26:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2786 extra nodes, 0 pruned nodes, max_depth=15
# [158]	test-rmse:129915	train-rmse:10569.4
# [09:26:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2478 extra nodes, 0 pruned nodes, max_depth=15
# [159]	test-rmse:129920	train-rmse:10532.7
# [09:26:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1444 extra nodes, 0 pruned nodes, max_depth=15
# [160]	test-rmse:129921	train-rmse:10516.1
# [09:26:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2756 extra nodes, 0 pruned nodes, max_depth=15
# [161]	test-rmse:129927	train-rmse:10477.8
# [09:26:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2826 extra nodes, 0 pruned nodes, max_depth=15
# [162]	test-rmse:129932	train-rmse:10445.4
# [09:26:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2282 extra nodes, 0 pruned nodes, max_depth=15
# [163]	test-rmse:129936	train-rmse:10415.3
# [09:26:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2112 extra nodes, 0 pruned nodes, max_depth=15
# [164]	test-rmse:129941	train-rmse:10395.5
# [09:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2528 extra nodes, 0 pruned nodes, max_depth=15
# [165]	test-rmse:129943	train-rmse:10368.8
# [09:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1302 extra nodes, 0 pruned nodes, max_depth=15
# [166]	test-rmse:129944	train-rmse:10352.3
# [09:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1682 extra nodes, 0 pruned nodes, max_depth=15
# [167]	test-rmse:129945	train-rmse:10324
# [09:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1754 extra nodes, 0 pruned nodes, max_depth=15
# [168]	test-rmse:129945	train-rmse:10296.5
# [09:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1866 extra nodes, 0 pruned nodes, max_depth=15
# [169]	test-rmse:129948	train-rmse:10273.5
# [09:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3468 extra nodes, 0 pruned nodes, max_depth=15
# [170]	test-rmse:129950	train-rmse:10241
# [09:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1208 extra nodes, 0 pruned nodes, max_depth=15
# [171]	test-rmse:129952	train-rmse:10225.7
# [09:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2080 extra nodes, 0 pruned nodes, max_depth=15
# [172]	test-rmse:129951	train-rmse:10199.1
# [09:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1554 extra nodes, 0 pruned nodes, max_depth=15
# [173]	test-rmse:129953	train-rmse:10175.9
# [09:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3366 extra nodes, 0 pruned nodes, max_depth=15
# [174]	test-rmse:129953	train-rmse:10138.6
# [09:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2736 extra nodes, 0 pruned nodes, max_depth=15
# [175]	test-rmse:129956	train-rmse:10109.9
# [09:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1584 extra nodes, 0 pruned nodes, max_depth=15
# [176]	test-rmse:129956	train-rmse:10100
# [09:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1412 extra nodes, 0 pruned nodes, max_depth=15
# [177]	test-rmse:129954	train-rmse:10087.9
# [09:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2378 extra nodes, 0 pruned nodes, max_depth=15
# [178]	test-rmse:129955	train-rmse:10067.5
# [09:26:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1440 extra nodes, 0 pruned nodes, max_depth=15
# [179]	test-rmse:129956	train-rmse:10054.2
# [09:26:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2234 extra nodes, 0 pruned nodes, max_depth=15
# [180]	test-rmse:129955	train-rmse:10036.2
# [09:26:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2350 extra nodes, 0 pruned nodes, max_depth=15
# [181]	test-rmse:129957	train-rmse:10016.5
# [09:26:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1800 extra nodes, 0 pruned nodes, max_depth=15
# [182]	test-rmse:129956	train-rmse:10010.5
# [09:26:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 686 extra nodes, 0 pruned nodes, max_depth=15
# [183]	test-rmse:129956	train-rmse:10006.5
# [09:26:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1538 extra nodes, 0 pruned nodes, max_depth=15
# [184]	test-rmse:129957	train-rmse:9999.14
# [09:26:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1502 extra nodes, 0 pruned nodes, max_depth=15
# [185]	test-rmse:129958	train-rmse:9988.34
# [09:26:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1310 extra nodes, 0 pruned nodes, max_depth=15
# [186]	test-rmse:129957	train-rmse:9982.45
# [09:26:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1254 extra nodes, 0 pruned nodes, max_depth=15
# [187]	test-rmse:129958	train-rmse:9971.4
# [09:26:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1228 extra nodes, 0 pruned nodes, max_depth=15
# [188]	test-rmse:129960	train-rmse:9961.2
# [09:26:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 886 extra nodes, 0 pruned nodes, max_depth=15
# [189]	test-rmse:129960	train-rmse:9958.31
# [09:26:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2498 extra nodes, 0 pruned nodes, max_depth=15
# [190]	test-rmse:129962	train-rmse:9935.48
# [09:26:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1432 extra nodes, 0 pruned nodes, max_depth=15
# [191]	test-rmse:129962	train-rmse:9926.94
# [09:26:22] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2564 extra nodes, 0 pruned nodes, max_depth=15
# [192]	test-rmse:129962	train-rmse:9904.75
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1388 extra nodes, 0 pruned nodes, max_depth=15
# [193]	test-rmse:129967	train-rmse:9885.94
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1030 extra nodes, 0 pruned nodes, max_depth=15
# [194]	test-rmse:129967	train-rmse:9879.55
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1654 extra nodes, 0 pruned nodes, max_depth=15
# [195]	test-rmse:129969	train-rmse:9869.36
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2138 extra nodes, 0 pruned nodes, max_depth=15
# [196]	test-rmse:129971	train-rmse:9848.56
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2406 extra nodes, 0 pruned nodes, max_depth=15
# [197]	test-rmse:129972	train-rmse:9831.26
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1848 extra nodes, 0 pruned nodes, max_depth=15
# [198]	test-rmse:129974	train-rmse:9821.59
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 948 extra nodes, 0 pruned nodes, max_depth=15
# [199]	test-rmse:129973	train-rmse:9815.29
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3310 extra nodes, 0 pruned nodes, max_depth=15
# [200]	test-rmse:129974	train-rmse:9788.6
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1936 extra nodes, 0 pruned nodes, max_depth=15
# [201]	test-rmse:129973	train-rmse:9779.58
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2076 extra nodes, 0 pruned nodes, max_depth=15
# [202]	test-rmse:129975	train-rmse:9763.43
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1606 extra nodes, 0 pruned nodes, max_depth=15
# [203]	test-rmse:129975	train-rmse:9750.8
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2544 extra nodes, 0 pruned nodes, max_depth=15
# [204]	test-rmse:129976	train-rmse:9734.79
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2350 extra nodes, 0 pruned nodes, max_depth=15
# [205]	test-rmse:129975	train-rmse:9723.04
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1054 extra nodes, 0 pruned nodes, max_depth=15
# [206]	test-rmse:129976	train-rmse:9715.85
# [09:26:23] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2262 extra nodes, 0 pruned nodes, max_depth=15
# [207]	test-rmse:129977	train-rmse:9693.2
# [09:26:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1006 extra nodes, 0 pruned nodes, max_depth=15
# [208]	test-rmse:129978	train-rmse:9689.41
# [09:26:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1202 extra nodes, 0 pruned nodes, max_depth=15
# [209]	test-rmse:129979	train-rmse:9680.86
# [09:26:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2052 extra nodes, 0 pruned nodes, max_depth=15
# [210]	test-rmse:129980	train-rmse:9671.23
# [09:26:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2126 extra nodes, 0 pruned nodes, max_depth=15
# [211]	test-rmse:129982	train-rmse:9658.25
# [09:26:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1680 extra nodes, 0 pruned nodes, max_depth=15
# [212]	test-rmse:129983	train-rmse:9652.65
# [09:26:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2058 extra nodes, 0 pruned nodes, max_depth=15
# [213]	test-rmse:129983	train-rmse:9634.81
# [09:26:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1240 extra nodes, 0 pruned nodes, max_depth=15
# [214]	test-rmse:129984	train-rmse:9627.87
# [09:26:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 4342 extra nodes, 0 pruned nodes, max_depth=15
# [215]	test-rmse:129990	train-rmse:9590.48
# [09:26:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1302 extra nodes, 0 pruned nodes, max_depth=15
# [216]	test-rmse:129989	train-rmse:9580.22
# [09:26:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2180 extra nodes, 0 pruned nodes, max_depth=15
# [217]	test-rmse:129990	train-rmse:9573.6
# [09:26:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2482 extra nodes, 0 pruned nodes, max_depth=15
# [218]	test-rmse:129989	train-rmse:9561.75
# [09:26:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3074 extra nodes, 0 pruned nodes, max_depth=15
# [219]	test-rmse:129991	train-rmse:9542.78
# [09:26:24] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1920 extra nodes, 0 pruned nodes, max_depth=15
# [220]	test-rmse:129990	train-rmse:9536.07
# [09:26:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2998 extra nodes, 0 pruned nodes, max_depth=15
# [221]	test-rmse:129992	train-rmse:9521.51
# [09:26:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1484 extra nodes, 0 pruned nodes, max_depth=15
# [222]	test-rmse:129992	train-rmse:9512.84
# [09:26:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1154 extra nodes, 0 pruned nodes, max_depth=15
# [223]	test-rmse:129992	train-rmse:9506.07
# [09:26:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1790 extra nodes, 0 pruned nodes, max_depth=15
# [224]	test-rmse:129990	train-rmse:9497.76
# [09:26:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1532 extra nodes, 0 pruned nodes, max_depth=15
# [225]	test-rmse:129991	train-rmse:9496.19
# [09:26:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1184 extra nodes, 0 pruned nodes, max_depth=15
# [226]	test-rmse:129990	train-rmse:9494.75
# [09:26:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1024 extra nodes, 0 pruned nodes, max_depth=15
# [227]	test-rmse:129991	train-rmse:9492.81
# [09:26:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1682 extra nodes, 0 pruned nodes, max_depth=15
# [228]	test-rmse:129990	train-rmse:9484.31
# [09:26:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1918 extra nodes, 0 pruned nodes, max_depth=15
# [229]	test-rmse:129990	train-rmse:9472.09
# [09:26:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 684 extra nodes, 0 pruned nodes, max_depth=15
# [230]	test-rmse:129990	train-rmse:9470.21
# [09:26:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2268 extra nodes, 0 pruned nodes, max_depth=15
# [231]	test-rmse:129991	train-rmse:9455.37
# [09:26:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 936 extra nodes, 0 pruned nodes, max_depth=15
# [232]	test-rmse:129990	train-rmse:9451.08
# [09:26:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2072 extra nodes, 0 pruned nodes, max_depth=15
# [233]	test-rmse:129991	train-rmse:9442.91
# [09:26:25] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2706 extra nodes, 0 pruned nodes, max_depth=15
# [234]	test-rmse:129993	train-rmse:9430.05
# [09:26:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1800 extra nodes, 0 pruned nodes, max_depth=15
# [235]	test-rmse:129991	train-rmse:9422.8
# [09:26:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1714 extra nodes, 0 pruned nodes, max_depth=15
# [236]	test-rmse:129991	train-rmse:9419.65
# [09:26:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1974 extra nodes, 0 pruned nodes, max_depth=15
# [237]	test-rmse:129992	train-rmse:9412.9
# [09:26:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1280 extra nodes, 0 pruned nodes, max_depth=15
# [238]	test-rmse:129992	train-rmse:9408.09
# [09:26:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 582 extra nodes, 0 pruned nodes, max_depth=15
# [239]	test-rmse:129992	train-rmse:9406.99
# [09:26:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2146 extra nodes, 0 pruned nodes, max_depth=15
# [240]	test-rmse:129993	train-rmse:9401.37
# [09:26:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3164 extra nodes, 0 pruned nodes, max_depth=15
# [241]	test-rmse:129995	train-rmse:9390.1
# [09:26:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2028 extra nodes, 0 pruned nodes, max_depth=15
# [242]	test-rmse:129995	train-rmse:9385.74
# [09:26:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2056 extra nodes, 0 pruned nodes, max_depth=15
# [243]	test-rmse:129996	train-rmse:9382.08
# [09:26:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1974 extra nodes, 0 pruned nodes, max_depth=15
# [244]	test-rmse:129997	train-rmse:9375.49
# [09:26:26] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1036 extra nodes, 0 pruned nodes, max_depth=15
# ...
# [918]	test-rmse:130057	train-rmse:8985.57
# [09:27:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2156 extra nodes, 0 pruned nodes, max_depth=15
# [919]	test-rmse:130057	train-rmse:8985.57
# [09:27:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1566 extra nodes, 0 pruned nodes, max_depth=15
# [920]	test-rmse:130057	train-rmse:8985.57
# [09:27:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 0 pruned nodes, max_depth=15
# [921]	test-rmse:130057	train-rmse:8985.57
# [09:27:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 730 extra nodes, 0 pruned nodes, max_depth=15
# [922]	test-rmse:130057	train-rmse:8985.57
# [09:27:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3880 extra nodes, 0 pruned nodes, max_depth=15
# [923]	test-rmse:130057	train-rmse:8985.57
# [09:27:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 760 extra nodes, 0 pruned nodes, max_depth=15
# [924]	test-rmse:130057	train-rmse:8985.57
# [09:27:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1818 extra nodes, 0 pruned nodes, max_depth=15
# [925]	test-rmse:130057	train-rmse:8985.57
# [09:27:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 0 pruned nodes, max_depth=15
# [926]	test-rmse:130057	train-rmse:8985.57
# [09:27:14] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1380 extra nodes, 0 pruned nodes, max_depth=15
# [927]	test-rmse:130057	train-rmse:8985.57
# [09:27:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2610 extra nodes, 0 pruned nodes, max_depth=15
# [928]	test-rmse:130057	train-rmse:8985.57
# [09:27:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2364 extra nodes, 0 pruned nodes, max_depth=15
# [929]	test-rmse:130057	train-rmse:8985.57
# [09:27:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2908 extra nodes, 0 pruned nodes, max_depth=15
# [930]	test-rmse:130057	train-rmse:8985.57
# [09:27:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2956 extra nodes, 0 pruned nodes, max_depth=15
# [931]	test-rmse:130057	train-rmse:8985.57
# [09:27:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2868 extra nodes, 0 pruned nodes, max_depth=15
# [932]	test-rmse:130057	train-rmse:8985.57
# [09:27:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2842 extra nodes, 0 pruned nodes, max_depth=15
# [933]	test-rmse:130057	train-rmse:8985.57
# [09:27:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3204 extra nodes, 0 pruned nodes, max_depth=15
# [934]	test-rmse:130057	train-rmse:8985.57
# [09:27:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2986 extra nodes, 0 pruned nodes, max_depth=15
# [935]	test-rmse:130057	train-rmse:8985.57
# [09:27:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2614 extra nodes, 0 pruned nodes, max_depth=15
# [936]	test-rmse:130057	train-rmse:8985.57
# [09:27:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2244 extra nodes, 0 pruned nodes, max_depth=15
# [937]	test-rmse:130057	train-rmse:8985.57
# [09:27:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1198 extra nodes, 0 pruned nodes, max_depth=15
# [938]	test-rmse:130057	train-rmse:8985.57
# [09:27:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2588 extra nodes, 0 pruned nodes, max_depth=15
# [939]	test-rmse:130057	train-rmse:8985.57
# [09:27:15] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2790 extra nodes, 0 pruned nodes, max_depth=15
# [940]	test-rmse:130057	train-rmse:8985.57
# [09:27:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2480 extra nodes, 0 pruned nodes, max_depth=15
# [941]	test-rmse:130057	train-rmse:8985.57
# [09:27:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1144 extra nodes, 0 pruned nodes, max_depth=15
# [942]	test-rmse:130057	train-rmse:8985.57
# [09:27:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1250 extra nodes, 0 pruned nodes, max_depth=15
# [943]	test-rmse:130057	train-rmse:8985.57
# [09:27:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 806 extra nodes, 0 pruned nodes, max_depth=15
# [944]	test-rmse:130057	train-rmse:8985.57
# [09:27:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1992 extra nodes, 0 pruned nodes, max_depth=15
# [945]	test-rmse:130057	train-rmse:8985.57
# [09:27:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 938 extra nodes, 0 pruned nodes, max_depth=15
# [946]	test-rmse:130057	train-rmse:8985.57
# [09:27:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2138 extra nodes, 0 pruned nodes, max_depth=15
# [947]	test-rmse:130057	train-rmse:8985.57
# [09:27:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1258 extra nodes, 0 pruned nodes, max_depth=15
# [948]	test-rmse:130057	train-rmse:8985.57
# [09:27:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1226 extra nodes, 0 pruned nodes, max_depth=15
# [949]	test-rmse:130057	train-rmse:8985.57
# [09:27:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1898 extra nodes, 0 pruned nodes, max_depth=15
# [950]	test-rmse:130057	train-rmse:8985.57
# [09:27:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1364 extra nodes, 0 pruned nodes, max_depth=15
# [951]	test-rmse:130057	train-rmse:8985.57
# [09:27:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1154 extra nodes, 0 pruned nodes, max_depth=15
# [952]	test-rmse:130057	train-rmse:8985.57
# [09:27:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1866 extra nodes, 0 pruned nodes, max_depth=15
# [953]	test-rmse:130057	train-rmse:8985.57
# [09:27:16] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2128 extra nodes, 0 pruned nodes, max_depth=15
# [954]	test-rmse:130057	train-rmse:8985.57
# [09:27:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 832 extra nodes, 0 pruned nodes, max_depth=15
# [955]	test-rmse:130057	train-rmse:8985.57
# [09:27:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2468 extra nodes, 0 pruned nodes, max_depth=15
# [956]	test-rmse:130057	train-rmse:8985.57
# [09:27:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2182 extra nodes, 0 pruned nodes, max_depth=15
# [957]	test-rmse:130057	train-rmse:8985.57
# [09:27:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1624 extra nodes, 0 pruned nodes, max_depth=15
# [958]	test-rmse:130057	train-rmse:8985.57
# [09:27:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1850 extra nodes, 0 pruned nodes, max_depth=15
# [959]	test-rmse:130057	train-rmse:8985.57
# [09:27:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2736 extra nodes, 0 pruned nodes, max_depth=15
# [960]	test-rmse:130057	train-rmse:8985.57
# [09:27:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 672 extra nodes, 0 pruned nodes, max_depth=15
# [961]	test-rmse:130057	train-rmse:8985.57
# [09:27:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2190 extra nodes, 0 pruned nodes, max_depth=15
# [962]	test-rmse:130057	train-rmse:8985.57
# [09:27:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1290 extra nodes, 0 pruned nodes, max_depth=15
# [963]	test-rmse:130057	train-rmse:8985.57
# [09:27:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2886 extra nodes, 0 pruned nodes, max_depth=15
# [964]	test-rmse:130057	train-rmse:8985.57
# [09:27:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3372 extra nodes, 0 pruned nodes, max_depth=15
# [965]	test-rmse:130057	train-rmse:8985.57
# [09:27:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1560 extra nodes, 0 pruned nodes, max_depth=15
# [966]	test-rmse:130057	train-rmse:8985.57
# [09:27:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1516 extra nodes, 0 pruned nodes, max_depth=15
# [967]	test-rmse:130057	train-rmse:8985.57
# [09:27:17] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 976 extra nodes, 0 pruned nodes, max_depth=15
# [968]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1016 extra nodes, 0 pruned nodes, max_depth=15
# [969]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2486 extra nodes, 0 pruned nodes, max_depth=15
# [970]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 646 extra nodes, 0 pruned nodes, max_depth=15
# [971]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 628 extra nodes, 0 pruned nodes, max_depth=15
# [972]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 900 extra nodes, 0 pruned nodes, max_depth=15
# [973]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1586 extra nodes, 0 pruned nodes, max_depth=15
# [974]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3378 extra nodes, 0 pruned nodes, max_depth=15
# [975]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2474 extra nodes, 0 pruned nodes, max_depth=15
# [976]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3016 extra nodes, 0 pruned nodes, max_depth=15
# [977]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 694 extra nodes, 0 pruned nodes, max_depth=15
# [978]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1986 extra nodes, 0 pruned nodes, max_depth=15
# [979]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 974 extra nodes, 0 pruned nodes, max_depth=15
# [980]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 976 extra nodes, 0 pruned nodes, max_depth=15
# [981]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 920 extra nodes, 0 pruned nodes, max_depth=15
# [982]	test-rmse:130057	train-rmse:8985.57
# [09:27:18] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1740 extra nodes, 0 pruned nodes, max_depth=15
# [983]	test-rmse:130057	train-rmse:8985.57
# [09:27:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1748 extra nodes, 0 pruned nodes, max_depth=15
# [984]	test-rmse:130057	train-rmse:8985.57
# [09:27:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3688 extra nodes, 0 pruned nodes, max_depth=15
# [985]	test-rmse:130057	train-rmse:8985.57
# [09:27:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2264 extra nodes, 0 pruned nodes, max_depth=15
# [986]	test-rmse:130057	train-rmse:8985.57
# [09:27:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3272 extra nodes, 0 pruned nodes, max_depth=15
# [987]	test-rmse:130057	train-rmse:8985.57
# [09:27:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 946 extra nodes, 0 pruned nodes, max_depth=15
# [988]	test-rmse:130057	train-rmse:8985.57
# [09:27:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 3162 extra nodes, 0 pruned nodes, max_depth=15
# [989]	test-rmse:130057	train-rmse:8985.57
# [09:27:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2622 extra nodes, 0 pruned nodes, max_depth=15
# [990]	test-rmse:130057	train-rmse:8985.57
# [09:27:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1196 extra nodes, 0 pruned nodes, max_depth=15
# [991]	test-rmse:130057	train-rmse:8985.57
# [09:27:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1030 extra nodes, 0 pruned nodes, max_depth=15
# [992]	test-rmse:130057	train-rmse:8985.57
# [09:27:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2672 extra nodes, 0 pruned nodes, max_depth=15
# [993]	test-rmse:130057	train-rmse:8985.57
# [09:27:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2794 extra nodes, 0 pruned nodes, max_depth=15
# [994]	test-rmse:130057	train-rmse:8985.57
# [09:27:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 2452 extra nodes, 0 pruned nodes, max_depth=15
# [995]	test-rmse:130057	train-rmse:8985.57
# [09:27:19] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1136 extra nodes, 0 pruned nodes, max_depth=15
# [996]	test-rmse:130057	train-rmse:8985.57
# [09:27:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1204 extra nodes, 0 pruned nodes, max_depth=15
# [997]	test-rmse:130057	train-rmse:8985.57
# [09:27:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1008 extra nodes, 0 pruned nodes, max_depth=15
# [998]	test-rmse:130057	train-rmse:8985.57
# [09:27:20] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 1378 extra nodes, 0 pruned nodes, max_depth=15
# [999]	test-rmse:130057	train-rmse:8985.57

# %%
predict_vals = xgb_model.predict(dtest)

# %%
predict_vals
# Out:
# array([568521.25, 473422.1 , 366565.47, ..., 530962.25, 632490.4 ,
#        542576.06], dtype=float32)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(predict_vals, y_test)
# Out:
# 16914813193.85936

# %%
xgb.plot_importance(xgb_model);
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# [XGBoost параметры](https://xgboost.readthedocs.io/en/latest/):
#
# Выделяют три группы параметров:
# - Общие параметры, отвечающие за базовый алгоритм для бустинга и распараллеливание.
# - Параметры выбранного базового алгоритма.
# - Параметры обучения, отвечающие за функцию потерь и метрику качества на валидации.
#
# **1. Общие параметры:**
# - booster [default=gbtree] - тип базового алгоритма для бустинга: дерево решений gbtree или линейная модель gblinear.
# - silent [default=0] - выдавать (silent=0) или нет (silent=1) сообщения по ходу работы алгоритма.
# - nthread [default to maximum number of threads available if not set] - число нитей доступных для параллельной работы xgboost.
#
# **2. Параметры базового алгоритма:**
#
# **2.1. Дерево решений:**
# - eta [default=0.3] - темп обучения, перед добавлением дерева в композицию оно умножается на eta. Используется для предотвращения переобучения за счёт "сокращения" весов базовых алгоритмов, делая модель более консервативной. Чем меньше eta, тем больше нужно итераций num_boost_round для обучения модели с хорошим качеством. Диапазон: [0, 1]
# - gamma [default=0] - минимальное снижение значения функции потерь, необходимое для дальнейшего разбиения вершины дерева. Большие значения gamma > 0 приводят к более консервативным моделям. Диапазон: [0, $\infty$).
# - max_depth [default=6] - максимальная глубина дерева. Диапазон: [1, $\infty$).
# - min_child_weight [default=1] - минимальное необходимое (взвешенное) число примеров в каждой вершине. Чем больше, тем более консервативна итоговая модель. Диапазон: [0, $\infty$).
# - max_delta_step [default=0] - обычно равен нулю. Положительные значения используются при несбалансированных классах для ускорения сходимости. Диапазон [0, $\infty$).
# - subsample [default=1] - доля выборки, используемая для обучения каждого дерева. Если subsample < 1, то выбирается случайная подвыборка, что помогает в борьбе с переобучением. Диапазон: (0, 1]
# - colsample_bytree [default=1] - доля признаков, используемая для обучения каждого дерева. Диапазон: (0, 1]
# - lambda [default=1] - коэффициент перед $L_2$-регуляризатором в функции потерь.
# - alpha [default=0] - коэффициент перед $L_1$-регуляризатором в функции потерь.
#
# **2.2. Линейная модель:**
# - lambda [default=0] - коэффициент перед $L_2$-регуляризатором вектора весов в функции потерь.
# - alpha [default=0] - коэффициент перед $L_1$-регуляризатором вектора весов в функции потерь.
# - lambda_bias [default=0] - коэффициент перед $L_2$-регуляризатором смещения (свободного члена) в функции потерь.
#
# **3. Параметры задачи обучения:**
# - objective [default=reg:linear] - используемая при обучении функция потерь:
#     - "reg:linear" – линейная регрессия.
#     - "reg:logistic" – логистическая регрессия.
#     - "binary:logistic" – логистическая регрессия для бинарной классификации, на выходе - вероятность.
#     - "binary:logitraw" – то же самое, но на выходе - значение до его преобразования логистической функцией.
#     - "count:poisson" – регрессия Пуассона (используется для оценки числа каких-то событий, счётный признак), на выходе - матожидания распределения Пуассона. В этом случае max_delta_step автоматически устанавливается равным 0.7.
#     - "multi:softmax" – обобщение логистической регрессии на многоклассовый случай. При этом нужно задать параметр num_class.
#     - "multi:softprob" – то же самое, но на выходе - вектор размера ndata * nclass, который можно преобразовать в матрицу, содержащую вероятности отнесения данного объекта к данному классу.
#     - "rank:pairwise" – используется для задач ранжирования.
# - base_score [default=0.5] - инициализация значения модели для всех примеров, глобальное смещение.
# - eval_metric [default according to objective] - метрика качества на валидационной выборке (по умолчанию соответствует функции потерь: rmse - для регрессии, error - для классификации, mean average precision - для ранжирования). Выбрать можно одну из следующих метрик:
#     - "rmse": root mean square error.
#     - "logloss": минус логарифм правдоподобия.
#     - "error": доля ошибок для бинарной классификации.
#     - "merror": то же самое для многоклассовой классификации.
#     - "mlogloss": logloss для многоклассовой классификации.
#     - "auc": AUC.
#     - "ndcg": Normalized Discounted Cumulative Gain.
#     - "map": Mean average precision.
#     - "ndcg@n",”map@n”: здесь n - целое число, первые n позиций в списке не учитываются.
#     - "ndcg-",”map-”,”ndcg@n-”,”map@n-”: списку из всех положительных примеров будет присвоено значение 0 (вместо 1).
# - seed [default=0] - для воспроизводимости "случайности".
#
# **Параметры в xgboost.train**:
# - params (dict) – параметры, описанные выше.
# - dtrain (DMatrix) – обучающая выборка.
# - num_boost_round (int) – число итераций бустинга.
# - evals (list) – список для оценки качества во время обучения.
# - obj (function) – собственная функция потерь.
# - feval (function) – собственная функция для оценки качества.
# - maximize (bool) – нужно ли максимизировать feval.
# - early_stopping_rounds (int) – активирует early stopping. Ошибка на валидации должна уменьшаться каждые early_stopping_rounds итераций для продолжения обучения. Список evals должен быть не пуст. Возвращается модель с последней итерации. Если произошел ранний останов, то модель будет содержать поля: bst.best_score и bst.best_iteration.
# - evals_result (dict) – результаты оценки качества.
# - verbose_eval (bool) – вывод значения метрики качества на каждой итерации бустинга.
# - learning_rates (list or function) – коэффициент скорости обучения для каждой итерации - list l: eta = l[boosting round] - function f: eta = f(boosting round, num_boost_round).
# - xgb_model (file name of stored xgb model or ‘Booster’ instance) – возможность продолжить обучения имеющейся модели XGB.
